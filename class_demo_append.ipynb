# %%
import pandas as pd

# %%
# df = pd.DataFrame(columns=['','title','word count','l1','l2','l3','l4','l5','l6','l7','l8'])
df = pd.DataFrame()

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
korean = pd.read_csv("../data/korean/lyricsKR0-100k_out.csv", index_col=0)

# %%
korean.head()
# Out:
#                                   title  word count        l1        l2  \
# https://www.lyrics.co.kr/?p=1       NaN         355  0.109859  0.174648
# https://www.lyrics.co.kr/?p=10      NaN         180  0.111111  0.177778
# https://www.lyrics.co.kr/?p=100     NaN         113  0.221239  0.345133
# https://www.lyrics.co.kr/?p=1000    NaN           6  0.166667  0.166667
# https://www.lyrics.co.kr/?p=10000   NaN         158  0.088608  0.189873
#
#                                          l3        l4        l5        l6  \
# https://www.lyrics.co.kr/?p=1      0.202817  0.242254  0.295775  0.346479
# https://www.lyrics.co.kr/?p=10     0.250000  0.305556  0.311111  0.383333
# https://www.lyrics.co.kr/?p=100    0.362832  0.362832  0.371681  0.398230
# https://www.lyrics.co.kr/?p=1000   0.166667  0.166667  0.166667  0.333333
# https://www.lyrics.co.kr/?p=10000  0.253165  0.297468  0.303797  0.348101
#
#                                          l7        l8
# ...

# %%
df = df.append(korean)
df.head()
# Out:
#                                   title  word count        l1        l2  \
# https://www.lyrics.co.kr/?p=1       NaN         355  0.109859  0.174648
# https://www.lyrics.co.kr/?p=10      NaN         180  0.111111  0.177778
# https://www.lyrics.co.kr/?p=100     NaN         113  0.221239  0.345133
# https://www.lyrics.co.kr/?p=1000    NaN           6  0.166667  0.166667
# https://www.lyrics.co.kr/?p=10000   NaN         158  0.088608  0.189873
#
#                                          l3        l4        l5        l6  \
# https://www.lyrics.co.kr/?p=1      0.202817  0.242254  0.295775  0.346479
# https://www.lyrics.co.kr/?p=10     0.250000  0.305556  0.311111  0.383333
# https://www.lyrics.co.kr/?p=100    0.362832  0.362832  0.371681  0.398230
# https://www.lyrics.co.kr/?p=1000   0.166667  0.166667  0.166667  0.333333
# https://www.lyrics.co.kr/?p=10000  0.253165  0.297468  0.303797  0.348101
#
#                                          l7        l8
# ...
