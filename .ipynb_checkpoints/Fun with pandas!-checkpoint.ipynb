# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#allow the generated plots to appear in this notebook
# %matplotlib inline

# %%
#import data
import pandas as pd
df = pd.read_csv('../data/NST-EST2013-01.csv')
df
# Out:
#           Geographic Area       Census Estimates Base         2010  \
# 0           United States  308,745,538    308,747,716  309,326,295
# 1               Northeast   55,317,240     55,317,261   55,376,322
# 2                 Midwest   66,927,001     66,927,549   66,976,321
# 3                   South  114,555,744    114,557,273  114,857,899
# 4                    West   71,945,553     71,945,633   72,115,753
# 5                .Alabama    4,779,736      4,779,758    4,785,570
# 6                 .Alaska      710,231        710,231      713,868
# 7                .Arizona    6,392,017      6,392,015    6,408,790
# 8               .Arkansas    2,915,918      2,915,916    2,922,280
# 9             .California   37,253,956     37,253,959   37,333,601
# 10              .Colorado    5,029,196      5,029,196    5,048,196
# 11           .Connecticut    3,574,097      3,574,097    3,579,210
# 12              .Delaware      897,934        897,936      899,711
# ...

# %%
# df.apply(pd.to_numeric)
cols = df.columns[1:]

for col in cols:
    df[col] = pd.to_numeric(df[col].map(lambda x: x.replace(",","")))

# %%
df.describe()
# Out:
#              Census  Estimates Base          2010          2011          2012  \
# count  5.700000e+01    5.700000e+01  5.700000e+01  5.700000e+01  5.700000e+01
# mean   1.631513e+07    1.631524e+07  1.634562e+07  1.646376e+07  1.658373e+07
# std    4.436075e+07    4.436108e+07  4.444656e+07  4.478101e+07  4.512143e+07
# min    5.636260e+05    5.636260e+05  5.642220e+05  5.673290e+05  5.766260e+05
# 25%    1.852994e+06    1.852999e+06  1.854146e+06  1.855184e+06  1.856680e+06
# 50%    4.625364e+06    4.625360e+06  4.636361e+06  4.673509e+06  4.723417e+06
# 75%    9.535483e+06    9.535471e+06  9.559533e+06  9.651377e+06  9.748364e+06
# max    3.087455e+08    3.087477e+08  3.093263e+08  3.115826e+08  3.138737e+08
#
#                2013
# count  5.700000e+01
# mean   1.670178e+07
# std    4.545510e+07
# min    5.826580e+05
# 25%    1.868516e+06
# 50%    4.774839e+06
# 75%    9.848060e+06
# max    3.161288e+08

# %%
df['2013'] - df['2012']
# Out:
# 0     2255154
# 1      171281
# 2      226465
# 3     1129461
# 4      727947
# 5       16194
# 6        4825
# 7       75475
# 8        9545
# 9      332643
# 10      78909
# 11       4315
# 12       8696
# 13      13022
# 14     232111
# 15      76521
# 16      13964
# 17      16546
# 18      13943
# 19      33120
# 20      15377
# 21       8559
# 22      15565
# 23      23336
# 24       -199
# 25      43946
# 26      47521
# 27      13103
# 28      40734
# 29       4757
# 30      19649
# 31       9671
# 32      13166
# 33      35782
# 34       1842
# 35      31590
# 36       1747
# 37      75002
# 38      99696
# 39      22048
# 40      17777
# 41      34788
# 42      30264
# 43       9326
# 44       1207
# 45      51422
# 46      10830
# 47      41064
# 48     387397
# 49      46001
# 50        677
# 51      73777
# 52      76088
# 53      -2376
# 54      18159
# 55       6032
# 56     -36459
# dtype: int64

# %%
df.Census.mean()
# Out:
# 16315129.877192982

# %%
df.Census.median()
# Out:
# 4625364.0

# %%
import matplotlib
# %matplotlib inline

df['2013'].hist(bins=20)
# Out:
# 308745538

# %%
df.sort_values('Census',ascending=False).tail(5)
# Out:
#           Geographic Area  Census  Estimates Base    2010    2011    2012  \
# 6                 .Alaska  710231          710231  713868  723375  730307
# 39          .North Dakota  672591          672591  674344  684867  701345
# 50               .Vermont  625741          625745  625793  626320  625953
# 13  .District of Columbia  601723          601767  605125  619624  633427
# 55               .Wyoming  563626          563626  564222  567329  576626
#
#       2013
# 6   735132
# 39  723393
# 50  626630
# 13  646449
# 55  582658
